# %%
! python3 -m pip install graphein
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting graphein
#   Downloading graphein-1.5.2.tar.gz (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.0/186.0 KB 13.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyyaml<6.*,>=5.1
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 KB 238.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting multipledispatch
#   Downloading multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (4.3.0)
# Requirement already satisfied: networkx in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (2.8.7)
# Requirement already satisfied: scikit-learn in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (1.1.2)
# Requirement already satisfied: scipy in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (1.9.1)
# Collecting plotly
#   Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 30.4 MB/s eta 0:00:00a 0:00:01
# Collecting biopandas>=0.4.1
#   Downloading biopandas-0.4.1-py2.py3-none-any.whl (878 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 KB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (1.23.3)
# Collecting xarray
#   Downloading xarray-2022.10.0-py3-none-any.whl (947 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 947.6/947.6 KB 34.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib>=3.4.3 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (3.6.0)
# Requirement already satisfied: tqdm in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (4.64.1)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pydantic
#   Downloading pydantic-1.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 72.5 MB/s eta 0:00:00a 0:00:01
# Collecting deepdiff
#   Downloading deepdiff-6.2.1-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 KB 294.4 MB/s eta 0:00:00
# Collecting bioservices>=1.10.0
#   Downloading bioservices-1.10.4.tar.gz (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 KB 257.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: biopython in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (1.79)
# Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 KB 261.7 MB/s eta 0:00:00
# Collecting rich-click
#   Downloading rich_click-1.5.2-py3-none-any.whl (20 kB)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 46.8 MB/s eta 0:00:00
# Requirement already satisfied: rich in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (12.6.0)
# Requirement already satisfied: pandas in /datastore/py_envs/ocml/lib/python3.10/site-packages (from graphein) (1.5.0)
# Requirement already satisfied: setuptools in /datastore/py_envs/ocml/lib/python3.10/site-packages (from biopandas>=0.4.1->graphein) (59.6.0)
# Requirement already satisfied: appdirs in /datastore/py_envs/ocml/lib/python3.10/site-packages (from bioservices>=1.10.0->graphein) (1.4.4)
# Requirement already satisfied: beautifulsoup4 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from bioservices>=1.10.0->graphein) (4.11.1)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting easydev>=0.12.0
#   Downloading easydev-0.12.0.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 KB 218.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting grequests
#   Downloading grequests-0.6.0-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: lxml in /datastore/py_envs/ocml/lib/python3.10/site-packages (from bioservices>=1.10.0->graphein) (4.9.1)
# Requirement already satisfied: requests in /datastore/py_envs/ocml/lib/python3.10/site-packages (from bioservices>=1.10.0->graphein) (2.28.1)
# Collecting requests_cache
#   Downloading requests_cache-0.9.6-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 KB 372.1 MB/s eta 0:00:00
# Collecting suds-community>=0.7
#   Downloading suds_community-1.1.2-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.9/144.9 KB 264.9 MB/s eta 0:00:00
# Requirement already satisfied: wrapt in /datastore/py_envs/ocml/lib/python3.10/site-packages (from bioservices>=1.10.0->graphein) (1.14.1)
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: packaging>=20.0 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from matplotlib>=3.4.3->graphein) (4.37.4)
# Requirement already satisfied: pytz>=2020.1 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from pandas->graphein) (2022.4)
# Collecting ordered-set<4.2.0,>=4.0.2
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: six in /datastore/py_envs/ocml/lib/python3.10/site-packages (from multipledispatch->graphein) (1.16.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from rich->graphein) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from rich->graphein) (0.9.1)
# Requirement already satisfied: click>=7 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from rich-click->graphein) (8.0.4)
# Requirement already satisfied: joblib>=1.0.0 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from scikit-learn->graphein) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from scikit-learn->graphein) (3.1.0)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pexpect in /datastore/py_envs/ocml/lib/python3.10/site-packages (from easydev>=0.12.0->bioservices>=1.10.0->graphein) (4.8.0)
# Requirement already satisfied: soupsieve>1.2 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from beautifulsoup4->bioservices>=1.10.0->graphein) (2.3.2.post1)
# Collecting gevent
#   Downloading gevent-22.10.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 47.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from requests->bioservices>=1.10.0->graphein) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from requests->bioservices>=1.10.0->graphein) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from requests->bioservices>=1.10.0->graphein) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from requests->bioservices>=1.10.0->graphein) (3.4)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting cattrs>=1.8
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: attrs>=21.2 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from requests_cache->bioservices>=1.10.0->graphein) (22.1.0)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.0.0rc9-py3-none-any.whl (12 kB)
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Collecting zope.interface
#   Downloading zope.interface-5.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.8/258.8 KB 112.7 MB/s eta 0:00:00
# Collecting greenlet<2.0,>=1.1.3
#   Downloading greenlet-1.1.3.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 KB 71.0 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /datastore/py_envs/ocml/lib/python3.10/site-packages (from pexpect->easydev>=0.12.0->bioservices>=1.10.0->graphein) (0.7.0)
# Building wheels for collected packages: graphein, bioservices, pyyaml, wget, easydev
#   Building wheel for graphein (pyproject.toml) ... done
#   Created wheel for graphein: filename=graphein-1.5.2-py3-none-any.whl size=199489 sha256=92b87d9d4b9cbaae758a9a574738e1ec35866e111849c5f2f1b21ec2a0fa3981
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gi6oe514/wheels/5c/50/e0/e41bc686f5dc3425699c14e8007b22b01ecd7eb6471b4f1e7b
#   Building wheel for bioservices (setup.py) ... done
#   Created wheel for bioservices: filename=bioservices-1.10.4-py3-none-any.whl size=230588 sha256=4945f1d1354fc521b941911e656afe0b995ad152b7ab90c67323e1c40cf0d895
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gi6oe514/wheels/2d/6a/c4/79c20d993774a3e1457308835cfda39d108880650143024099
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45656 sha256=4e3a46322861f11d382ca6f355b3770d15afc49cbbe04e17a07b545064decc39
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gi6oe514/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=8a65ca715418791985f7fd32582577ededc2a3393fb45043d5198ba848010d9f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gi6oe514/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for easydev (setup.py) ... done
#   Created wheel for easydev: filename=easydev-0.12.0-py3-none-any.whl size=64231 sha256=8ad138ea547d1ef5d334a6ba8eca7d23f9523a40a2fc1463b2f9a0401be1e6bd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gi6oe514/wheels/b6/ce/17/2e5a20cb830fe7f5f86da83fc81f7b68dd6e798fae7423cce9
# Successfully built graphein bioservices pyyaml wget easydev
# Installing collected packages: wget, zope.interface, zope.event, xmltodict, url-normalize, tenacity, suds-community, pyyaml, pydantic, ordered-set, multipledispatch, loguru, greenlet, exceptiongroup, colorlog, colorama, rich-click, plotly, gevent, easydev, deepdiff, cattrs, xarray, seaborn, requests_cache, grequests, biopandas, bioservices, graphein
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed biopandas-0.4.1 bioservices-1.10.4 cattrs-22.2.0 colorama-0.4.5 colorlog-6.7.0 deepdiff-6.2.1 easydev-0.12.0 exceptiongroup-1.0.0rc9 gevent-22.10.1 graphein-1.5.2 greenlet-1.1.3.post0 grequests-0.6.0 loguru-0.6.0 multipledispatch-0.6.0 ordered-set-4.1.0 plotly-5.10.0 pydantic-1.10.2 pyyaml-5.4.1 requests_cache-0.9.6 rich-click-1.5.2 seaborn-0.12.1 suds-community-1.1.2 tenacity-8.1.0 url-normalize-1.4.3 wget-3.2 xarray-2022.10.0 xmltodict-0.13.0 zope.event-4.5.0 zope.interface-5.5.0

# %%
import matplotlib.pyplot as plt
from graphein.protein.config import ProteinGraphConfig
from graphein.protein.graphs import construct_graph
from graphein.protein.visualisation import plot_protein_structure_graph
pg_config = ProteinGraphConfig()

fp = "query/HCMV_UL54.pdb"
pg = construct_graph(pg_config, pdb_path=fp)

# Plot
ax = plot_protein_structure_graph(pg, label_node_ids=False, colour_nodes_by="residue_name")
plt.show()


# not that interesting
# Out:
# Reading PDB file...         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Processing PDB dataframe... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
